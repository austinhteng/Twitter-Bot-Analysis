# %%
import pandas as pd
import matplotlib as plt

# %%
bot_tweets = pd.read_csv('./Tweet-Reader/botwiki-2019/bot_tweets.csv')

# %%
human_tweets = pd.read_csv('./Tweet-Reader/verified-2019/human_tweets.csv')

# %%
bot_tweets
# Out:
#        Unnamed: 0              User_ID Account_Type             Tweet_ID  \
# 0               0  1120973992754581509          bot  1139116069816344576
# 1               1  1120973992754581509          bot  1138934877351550976
# 2               2  1120973992754581509          bot  1138753680994439168
# 3               3  1120973992754581509          bot  1138572488357621761
# 4               4  1120973992754581509          bot  1138391293426655233
# ...           ...                  ...          ...                  ...
# 49481       49481   708394182595883008          bot  1502627285672685573
# 49482       49482   708394182595883008          bot  1502264905985978374
# 49483       49483   708394182595883008          bot  1501902753001467905
# 49484       49484   708394182595883008          bot  1501540414150508545
# 49485       49485   708394182595883008          bot  1501179572942819332
#
#                                                     Text  Retweet_Count  \
# ...

# %%
human_tweets
# Out:
#         Unnamed: 0    User_ID Account_Type             Tweet_ID  \
# 0                0   54619276        human  1537140410551787521
# 1                1   54619276        human  1537118075367079939
# 2                2   54619276        human  1537110260707643393
# 3                3   54619276        human  1537102450452312066
# 4                4   54619276        human  1537100623765819394
# ...            ...        ...          ...                  ...
# 192544      192544  436925910        human  1534168332940853248
# 192545      192545  436925910        human  1534152694662893568
# 192546      192546  436925910        human  1534152184694185985
# 192547      192547  436925910        human  1534021937818742784
# 192548      192548  436925910        human  1534001603916742657
#
#                                                      Text  Retweet_Count  \
# 0       “What Graham Greene saw clearly was the Americ...              1
# ...

# %%
total_chars = 0
for text in bot_tweets['Text']:
    total_chars += len(text)
print(total_chars / len(bot_tweets))
# Out:
# 82.72745827102615

# %%
total_chars = 0
for text in human_tweets['Text']:
    total_chars += len(text)
print(total_chars / len(human_tweets))
# Out:
# 132.17805337862052

# %%
bot_tweets['Date'][0]
curr_id = 0
tweet_count = 0
day_count = 0
frequency = pd.DataFrame(columns=['id', 'tweets/day'])
for tweet in bot_tweets.iterrow():
    if
# Out:
#   File "/tmp/ipykernel_4048/1600129222.py", line 4
#     for tweet in bot_tweets.iterrow():
#                                       ^
# IndentationError: expected an indented block

# %% [markdown]
# # Goals
# Compare frequency of posts
#
# Compare word clouds
